# %% [markdown]
# # Understanding the datatyes, null values , inconsistency of dataset

# %%
import pandas as pd
import numpy as np

# %%
# to load csv dataset
data = pd.read_csv('smart_hospital_appointment_dataset.csv')

# %%
# to get rows and columns in dataset
data.shape
# Out:
# (10000, 26)

# %%
#first 6 rows of dataset
data.head(6)
# Out:
#   patient_id  age  gender       city   bmi chronic_disease appointment_type  \
# 0  PAT_10000   52    Male     Mumbai  19.6    Hypertension        Scheduled
# 1  PAT_10001   21  Female     Mumbai  25.3             NaN        Scheduled
# 2  PAT_10002   51  Female  Bangalore  21.9             NaN        Scheduled
# 3  PAT_10003   78  Female      Delhi  31.7             NaN          Walk-in
# 4  PAT_10004   62  Female     Mumbai  24.7    Hypertension        Scheduled
# 5  PAT_10005   41  Female     Jaipur  25.3             NaN          Walk-in
#
#       department        symptoms severity_level  ...  waiting_time_minutes  \
# 0      Neurology        Headache            Low  ...                    43
# 1      Neurology        Headache            Low  ...                    44
# 2    Dermatology    Skin Allergy            Low  ...                    33
# 3    Orthopedics      Joint Pain            Low  ...                    59
# ...

# %%
#last 5 rows of dataset
data.tail(5)
# Out:
#      patient_id  age  gender       city   bmi chronic_disease  \
# 9995  PAT_19995   15    Male     Nagpur  17.2             NaN
# 9996  PAT_19996   70  Female       Pune  36.3             NaN
# 9997  PAT_19997   64  Female    Kolkata  27.3        Diabetes
# 9998  PAT_19998   21    Male  Hyderabad  27.0    Hypertension
# 9999  PAT_19999   82    Male     Jaipur  15.4    Hypertension
#
#      appointment_type        department        symptoms severity_level  ...  \
# 9995          Walk-in         Neurology        Headache           High  ...
# 9996          Walk-in        Cardiology      Chest Pain         Medium  ...
# 9997        Emergency     Ophthalmology  Eye Irritation            Low  ...
# 9998          Walk-in  Gastroenterology    Stomach Pain           High  ...
# 9999        Scheduled  General Medicine           Fever         Medium  ...
#
#       waiting_time_minutes  previous_appointments  \
# 9995                     8                      5
# ...

# %%
data.info()
#information about the columns of the dataset about datatypes
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   patient_id                    10000 non-null  str
#  1   age                           10000 non-null  int64
#  2   gender                        10000 non-null  str
#  3   city                          10000 non-null  str
#  4   bmi                           10000 non-null  float64
#  5   chronic_disease               5550 non-null   str
#  6   appointment_type              10000 non-null  str
#  7   department                    10000 non-null  str
#  8   symptoms                      10000 non-null  str
#  9   severity_level                10000 non-null  str
#  10  doctor_experience_years       10000 non-null  int64
#  11  consultation_fee              10000 non-null  int64
#  12  insurance                     10000 non-null  str
# ...

# %%
# to check sum of total null values in each column 
data.isnull().sum()
# chronic disease has 4450 null values NO DROP FOR NULL VALUES as it represent patient has no chronic disease
# Out:
# patient_id                         0
# age                                0
# gender                             0
# city                               0
# bmi                                0
# chronic_disease                 4450
# appointment_type                   0
# department                         0
# symptoms                           0
# severity_level                     0
# doctor_experience_years            0
# consultation_fee                   0
# insurance                          0
# appointment_day                    0
# appointment_month                  0
# booking_to_appointment_days        0
# waiting_time_minutes               0
# previous_appointments              0
# missed_previous_appointments       0
# hospital_rating                    0
# emergency_case                     0
# patient_satisfaction_score         0
# medicine_cost                      0
# test_cost                          0
# total_bill                         0
# ...

# %%
#get numerical (statistical Information) of the dataset like mean, min , max ,standard deviation
data.describe()
# mean of age is 45 , min 1 max 89
# mean of waiting time is 25min , minimum is 1min maximum is 59 min
# avg fees is 606 , min 220 , max 999
# Out:
#                 age           bmi  doctor_experience_years  consultation_fee  \
# count  10000.000000  10000.000000             10000.000000      10000.000000
# mean      45.000400     24.010890                15.399000        606.860700
# std       25.862836      3.935325                 8.604069        180.246694
# min        1.000000     15.000000                 1.000000        220.000000
# 25%       22.000000     21.300000                 8.000000        461.000000
# 50%       45.000000     24.000000                15.000000        609.000000
# 75%       68.000000     26.700000                23.000000        752.000000
# max       89.000000     39.800000                30.000000        999.000000
#
#        booking_to_appointment_days  waiting_time_minutes  \
# count                 10000.000000          10000.000000
# mean                     12.754500             25.203900
# std                       9.405715             14.862961
# ...

# %%
data.describe(include = 'object')
#describing categorical data of dataset like unique, top , frequency , count
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12996\2159399482.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include = 'object')
#        patient_id gender   city chronic_disease appointment_type  department  \
# count       10000  10000  10000            5550            10000       10000
# unique      10000      2     10               4                3          10
# top     PAT_10000   Male  Delhi        Diabetes        Scheduled  Cardiology
# freq            1   5005   1071            2034             5433        1075
#
# ...

# %%
#checking for dublicate rows in data
duplicate_count = data.duplicated().sum()

# %%
data["gender"].unique()
#CHECKING UNIQUE GENDER FOR ANY MISTAKE
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
#count of total Unique gender
data["gender"].nunique()
# Out:
# 2

# %%
#to get categorical columns 
categorical_columns = data.select_dtypes(include=["object", "string"]).columns

# %%
for col in categorical_columns:
    print(f"\nColumn: {col}")
    print(data[col].unique())
# Out:
# Column: patient_id
# <StringArray>
# ['PAT_10000', 'PAT_10001', 'PAT_10002', 'PAT_10003', 'PAT_10004', 'PAT_10005',
#  'PAT_10006', 'PAT_10007', 'PAT_10008', 'PAT_10009',
#  ...
#  'PAT_19990', 'PAT_19991', 'PAT_19992', 'PAT_19993', 'PAT_19994', 'PAT_19995',
#  'PAT_19996', 'PAT_19997', 'PAT_19998', 'PAT_19999']
# Length: 10000, dtype: str
#
# Column: gender
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
#
# Column: city
# <StringArray>
# [   'Mumbai', 'Bangalore',     'Delhi',    'Jaipur',   'Kolkata',   'Chennai',
#  'Hyderabad',      'Pune', 'Ahmedabad',    'Nagpur']
# Length: 10, dtype: str
#
# Column: chronic_disease
# <StringArray>
# ['Hypertension', nan, 'Diabetes', 'Asthma', 'Heart Disease']
# Length: 5, dtype: str
#
# Column: appointment_type
# <StringArray>
# ['Scheduled', 'Walk-in', 'Emergency']
# Length: 3, dtype: str
#
# Column: department
# <StringArray>
# [       'Neurology',      'Dermatology',      'Orthopedics',
# ...

# %%
#to verify that all data is genuine and realistic
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns

for col in numerical_columns:
    print(f"\nColumn: {col}")
    print("Minimum:", data[col].min())
    print("Maximum:", data[col].max())
# Out:
# Column: age
# Minimum: 1
# Maximum: 89
#
# Column: bmi
# Minimum: 15.0
# Maximum: 39.8
#
# Column: doctor_experience_years
# Minimum: 1
# Maximum: 30
#
# Column: consultation_fee
# Minimum: 220
# Maximum: 999
#
# Column: booking_to_appointment_days
# Minimum: 0
# Maximum: 29
#
# Column: waiting_time_minutes
# Minimum: 1
# Maximum: 59
#
# Column: previous_appointments
# Minimum: 0
# Maximum: 14
#
# Column: missed_previous_appointments
# Minimum: 0
# Maximum: 9
#
# Column: hospital_rating
# Minimum: 3.0
# Maximum: 5.0
#
# Column: emergency_case
# Minimum: 0
# Maximum: 1
#
# Column: patient_satisfaction_score
# Minimum: 7.6
# Maximum: 10.0
#
# Column: medicine_cost
# Minimum: 100
# Maximum: 19996
#
# Column: test_cost
# Minimum: 0
# Maximum: 14992
#
# Column: total_bill
# Minimum: 331.8
# Maximum: 34894.0

# %% [markdown]
# All categories have standard values and realistic numerical values .
# The dataset contains 10,000 rows and 26 columns with No dublicate values.
# Missing values exist only in the chronic_disease column (4,450 records), which indicates patients without any chronic conditions and will be handled during data cleaning.
